# %% [markdown]
# # formato simple con base de datos

# %%
import tkinter as tk
from tkinter import ttk
import sqlite3

# Conexión a la base de datos
conn = sqlite3.connect('registros.db')
c = conn.cursor()
c.execute('''
          CREATE TABLE IF NOT EXISTS entrenamientos
          (id INTEGER PRIMARY KEY AUTOINCREMENT,
           ejercicio TEXT,
           peso REAL,
           repeticiones INTEGER,
           peso_cargado REAL)
          ''')
conn.commit()

def reportar_avance():
    ejercicio = ejercicio_var.get()
    peso = float(peso_entry.get())
    repeticiones = int(repeticiones_entry.get())
    peso_cargado = peso * repeticiones

    c.execute("INSERT INTO entrenamientos (ejercicio, peso, repeticiones, peso_cargado) VALUES (?, ?, ?, ?)",
              (ejercicio, peso, repeticiones, peso_cargado))
    conn.commit()

    # Limpiar los campos después de agregar el registro
    peso_entry.delete(0, tk.END)
    repeticiones_entry.delete(0, tk.END)

def mostrar_registros():
    resultados.delete(1.0, tk.END)  # Limpiar el campo de texto

    c.execute("SELECT * FROM entrenamientos")
    registros = c.fetchall()

    for registro in registros:
        resultados.insert(tk.END, f"Ejercicio: {registro[1]}\n")
        resultados.insert(tk.END, f"Peso (kg): {registro[2]}\n")
        resultados.insert(tk.END, f"Repeticiones: {registro[3]}\n")
        resultados.insert(tk.END, f"Peso Cargado (kg): {registro[4]}\n")
        resultados.insert(tk.END, "-" * 20 + "\n")

# Crear la ventana principal
root = tk.Tk()
root.title("Registro de Avances")

# Nombres de los ejercicios
ejercicios = ["Press de Banca", "Dominadas", "Sentadillas", "Press de Hombros", "Curl de Bíceps"]

# Etiquetas y campos de entrada
ttk.Label(root, text="Ejercicio:").pack()
ejercicio_var = tk.StringVar()
ejercicio_menu = ttk.Combobox(root, textvariable=ejercicio_var, values=ejercicios, state="readonly")
ejercicio_menu.pack()

ttk.Label(root, text="Peso (kg):").pack()
peso_entry = ttk.Entry(root)
peso_entry.pack()

ttk.Label(root, text="Repeticiones:").pack()
repeticiones_entry = ttk.Entry(root)
repeticiones_entry.pack()

# Botones
reportar_button = ttk.Button(root, text="Reportar Avance", command=reportar_avance)
reportar_button.pack()

mostrar_button = ttk.Button(root, text="Mostrar Registros", command=mostrar_registros)
mostrar_button.pack()

# Campo de texto para mostrar registros
resultados = tk.Text(root, width=40, height=10)
resultados.pack()

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import sqlite3

# Conexión a la base de datos
conn = sqlite3.connect('registros.db')
c = conn.cursor()
c.execute('''
          CREATE TABLE IF NOT EXISTS entrenamientos
          (id INTEGER PRIMARY KEY AUTOINCREMENT,
           ejercicio TEXT,
           peso REAL,
           repeticiones INTEGER,
           peso_cargado REAL,
           fecha DATE)
          ''')
conn.commit()

def reportar_avance():
    ejercicio = ejercicio_var.get()
    peso = float(peso_entry.get())
    repeticiones = int(repeticiones_entry.get())
    peso_cargado = peso * repeticiones
    fecha = fecha_entry.get()  # Obtener la fecha

    c.execute("INSERT INTO entrenamientos (ejercicio, peso, repeticiones, peso_cargado, fecha) VALUES (?, ?, ?, ?, ?)",
              (ejercicio, peso, repeticiones, peso_cargado, fecha))
    conn.commit()

    # Limpiar los campos después de agregar el registro
    peso_entry.delete(0, tk.END)
    repeticiones_entry.delete(0, tk.END)
    fecha_entry.delete(0, tk.END)

def mostrar_registros():
    resultados.delete(1.0, tk.END)  # Limpiar el campo de texto

    c.execute("SELECT * FROM entrenamientos")
    registros = c.fetchall()

    for registro in registros:
        resultados.insert(tk.END, f"Ejercicio: {registro[1]}\n")
        resultados.insert(tk.END, f"Peso (kg): {registro[2]}\n")
        resultados.insert(tk.END, f"Repeticiones: {registro[3]}\n")
        resultados.insert(tk.END, f"Peso Cargado (kg): {registro[4]}\n")
        resultados.insert(tk.END, f"Fecha: {registro[5]}\n")  # Mostrar la fecha
        resultados.insert(tk.END, "-" * 20 + "\n")

# Resto del código permanece igual

# Etiquetas y campos de entrada para la fecha
ttk.Label(root, text="Fecha (AAAA-MM-DD):").pack()
fecha_entry = ttk.Entry(root)
fecha_entry.pack()

# Botones
reportar_button = ttk.Button(root, text="Reportar Avance", command=reportar_avance)
reportar_button.pack()

mostrar_button = ttk.Button(root, text="Mostrar Registros", command=mostrar_registros)
mostrar_button.pack()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# c:\Users\ASUS\OneDrive - Universidad de los Andes\Cricea-Notebooks\Proyectos personales\Gym.ipynb Cell 3 line <cell line: 52>()
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive%20-%20Universidad%20de%20los%20Andes/Cricea-Notebooks/Proyectos%20personales/Gym.ipynb#X10sZmlsZQ%3D%3D?line=46'>47</a>         resultados.insert(tk.END, "-" * 20 + "\n")
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive%20-%20Universidad%20de%20los%20Andes/Cricea-Notebooks/Proyectos%20personales/Gym.ipynb#X10sZmlsZQ%3D%3D?line=48'>49</a> # Resto del código permanece igual
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive%20-%20Universidad%20de%20los%20Andes/Cricea-Notebooks/Proyectos%20personales/Gym.ipynb#X10sZmlsZQ%3D%3D?line=49'>50</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive%20-%20Universidad%20de%20los%20Andes/Cricea-Notebooks/Proyectos%20personales/Gym.ipynb#X10sZmlsZQ%3D%3D?line=50'>51</a> # Etiquetas y campos de entrada para la fecha
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive%20-%20Universidad%20de%20los%20Andes/Cricea-Notebooks/Proyectos%20personales/Gym.ipynb#X10sZmlsZQ%3D%3D?line=51'>52</a> ttk.Label(root, text="Fecha (AAAA-MM-DD):").pack()
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive%20-%20Universidad%20de%20los%20Andes/Cricea-Notebooks/Proyectos%20personales/Gym.ipynb#X10sZmlsZQ%3D%3D?line=52'>53</a> fecha_entry = ttk.Entry(root)
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/OneDrive%20-%20Universidad%20de%20los%20Andes/Cricea-Notebooks/Proyectos%20personales/Gym.ipynb#X10sZmlsZQ%3D%3D?line=53'>54</a> fecha_entry.pack()
#
# File c:\Users\ASUS\anaconda3\lib\tkinter\ttk.py:754, in Label.__init__(self, master, **kw)
#     741 def __init__(self, master=None, **kw):
#     742     """Construct a Ttk Label with parent master.
#     743
#     744     STANDARD OPTIONS
#    (...)
#     752         relief, text, wraplength
#     753     """
# --> 754     Widget.__init__(self, master, "ttk::label", kw)
#
# File c:\Users\ASUS\anaconda3\lib\tkinter\ttk.py:552, in Widget.__init__(self, master, widgetname, kw)
#     549 if not getattr(master, '_tile_loaded', False):
#     550     # Load tile now, if needed
#     551     _load_tile(master)
# --> 552 tkinter.Widget.__init__(self, master, widgetname, kw=kw)
#
# File c:\Users\ASUS\anaconda3\lib\tkinter\__init__.py:2572, in BaseWidget.__init__(self, master, widgetName, cnf, kw, extra)
#    2570 for k, v in classes:
#    2571     del cnf[k]
# -> 2572 self.tk.call(
#    2573     (widgetName, self._w) + extra + self._options(cnf))
#    2574 for k, v in classes:
#    2575     k.configure(self, v)
#
# TclError: NULL main window
